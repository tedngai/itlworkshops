# %%
from bs4 import BeautifulSoup
import pandas as pd
import codecs

# %%
f = codecs.open("./FIT_salaryscrape.txt", "r")

data = []

soup = BeautifulSoup(f.read())
rows = soup.find_all('tr')
for row in rows[::2]:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols[1:] if ele])

# %%
labels = ['NAME', 'SCHOOL', 'SALARY', 'TYPE']
df = pd.DataFrame.from_records(data, columns=labels)

# %%
df
# Out:
#                              NAME                           SCHOOL    SALARY  \
# 0                  Brown, Joyce F  Fashion Institute of Technology  $431,499
# 1               Tuttle, Stephen P  Fashion Institute of Technology  $309,713
# 2                Richards, Troy A  Fashion Institute of Technology  $200,000
# 3                   Mak, Kam Hung  Fashion Institute of Technology  $176,308
# 4                 Reim, Melanie K  Fashion Institute of Technology  $174,329
# 5                   Armenia, Rita  Fashion Institute of Technology  $171,838
# 6                  Elins, Roberta  Fashion Institute of Technology  $171,320
# 7               Maiorca, Joseph J  Fashion Institute of Technology  $167,834
# 8                 Demers, Diane M  Fashion Institute of Technology  $165,250
# 9                 Cooper, Renee Y  Fashion Institute of Technology  $164,453
# 10             Buchman, Jeffrey S  Fashion Institute of Technology  $163,352
# 11           Silberman, Jeffrey P  Fashion Institute of Technology  $163,238
# 12              Sullivan, James J  Fashion Institute of Technology  $160,878
# 13              Federici, Mario P  Fashion Institute of Technology  $156,417
# 14                Edelstein, Jaye  Fashion Institute of Technology  $156,325
# 15            Cokkinos, Michael J  Fashion Institute of Technology  $156,110
# 16                   Wolf, Gary R  Fashion Institute of Technology  $154,934
# 17                    Su, Nancy Y  Fashion Institute of Technology  $152,220
# 18              Litowitz, Carol W  Fashion Institute of Technology  $150,156
# 19              Goldblatt, Mark M  Fashion Institute of Technology  $148,386
# 20   Klesenski-Rispoli, Deborah J  Fashion Institute of Technology  $146,966
# 21                Savola, Lasse T  Fashion Institute of Technology  $145,389
# 22                 Karp, Eileen A  Fashion Institute of Technology  $144,166
# 23                  Blanco, Pilar  Fashion Institute of Technology  $142,857
# 24               Cabrera, Mario L  Fashion Institute of Technology  $141,230
# 25             Martino, Anthony W  Fashion Institute of Technology  $139,965
# 26                 Rietman, Susan  Fashion Institute of Technology  $139,617
# 27              Schaye, Gilbert A  Fashion Institute of Technology  $138,905
# 28            Renzulli, Michael W  Fashion Institute of Technology  $138,905
# 29                Daykin, Susan M  Fashion Institute of Technology  $138,905
# ..                            ...                              ...       ...
# 347             Weisbroat, Paul J  Fashion Institute of Technology    $5,756
# 348                 Foley, Thomas  Fashion Institute of Technology    $5,088
# 349          Zatamei, Christopher  Fashion Institute of Technology    $4,829
# 350          Nascimento, Tobias C  Fashion Institute of Technology    $4,757
# 351                 Frunner, Sara  Fashion Institute of Technology    $4,512
# 352                Brodner, Steve  Fashion Institute of Technology    $4,070
# 353              Devries, David M  Fashion Institute of Technology    $4,010
# 354             Zivanic, Vasilija  Fashion Institute of Technology    $3,824
# 355         Washington, Michele Y  Fashion Institute of Technology    $3,748
# 356         Pogorelova, Lioubov A  Fashion Institute of Technology    $3,719
# 357      Allanson Bivens, Britt V  Fashion Institute of Technology    $3,604
# 358           Clancy, Elizabeth H  Fashion Institute of Technology    $3,568
# 359                    Liu, Dik F  Fashion Institute of Technology    $3,414
# 360                   Tokar, Inna  Fashion Institute of Technology    $3,352
# 361               Biolos, James M  Fashion Institute of Technology    $3,352
# 362                Pham, Mihn Dan  Fashion Institute of Technology    $3,316
# 363                   Kim, Woo Ah  Fashion Institute of Technology    $2,973
# 364                Khan, Fawzia N  Fashion Institute of Technology    $2,963
# 365               Sieper, Peter A  Fashion Institute of Technology    $2,890
# 366             Mooney, Jessica C  Fashion Institute of Technology    $2,379
# 367           Seitinger, Stefanie  Fashion Institute of Technology    $1,661
# 368            Zambrelli, Frank A  Fashion Institute of Technology      $500
# 369            Levinson, Jeanne L  Fashion Institute of Technology       $84
# 370     Pangburn, William Jameson  Fashion Institute of Technology       $81
# 371                 Sandler, Mark  Fashion Institute of Technology       $72
# 372              Dohner, Markus D  Fashion Institute of Technology       $72
# 373             Choudhary, Amod K  Fashion Institute of Technology       $72
# 374           Altieri, Joseph, Jr  Fashion Institute of Technology       $72
# 375                 Kyro, Stephen  Fashion Institute of Technology       $36
# 376              Atwi, Juliette A  Fashion Institute of Technology       $36
#
#                   TYPE
# 0    NYSTRS - Educator
# 1    NYSTRS - Educator
# 2    NYSTRS - Educator
# 3    NYSTRS - Educator
# 4    NYSTRS - Educator
# 5    NYSTRS - Educator
# 6    NYSTRS - Educator
# 7    NYSTRS - Educator
# 8    NYSTRS - Educator
# 9    NYSTRS - Educator
# 10   NYSTRS - Educator
# 11   NYSTRS - Educator
# 12   NYSTRS - Educator
# 13   NYSTRS - Educator
# 14   NYSTRS - Educator
# 15   NYSTRS - Educator
# 16   NYSTRS - Educator
# 17   NYSTRS - Educator
# 18   NYSTRS - Educator
# 19   NYSTRS - Educator
# 20   NYSTRS - Educator
# 21   NYSTRS - Educator
# 22   NYSTRS - Educator
# 23   NYSTRS - Educator
# 24   NYSTRS - Educator
# 25   NYSTRS - Educator
# 26   NYSTRS - Educator
# 27   NYSTRS - Educator
# 28   NYSTRS - Educator
# 29   NYSTRS - Educator
# ..                 ...
# 347  NYSTRS - Educator
# 348  NYSTRS - Educator
# 349  NYSTRS - Educator
# 350  NYSTRS - Educator
# 351  NYSTRS - Educator
# 352  NYSTRS - Educator
# 353  NYSTRS - Educator
# 354  NYSTRS - Educator
# 355  NYSTRS - Educator
# 356  NYSTRS - Educator
# 357  NYSTRS - Educator
# 358  NYSTRS - Educator
# 359  NYSTRS - Educator
# 360  NYSTRS - Educator
# 361  NYSTRS - Educator
# 362  NYSTRS - Educator
# 363  NYSTRS - Educator
# 364  NYSTRS - Educator
# 365  NYSTRS - Educator
# 366  NYSTRS - Educator
# 367  NYSTRS - Educator
# 368  NYSTRS - Educator
# 369  NYSTRS - Educator
# 370  NYSTRS - Educator
# 371  NYSTRS - Educator
# 372  NYSTRS - Educator
# 373  NYSTRS - Educator
# 374  NYSTRS - Educator
# 375  NYSTRS - Educator
# 376  NYSTRS - Educator
#
# [377 rows x 4 columns]

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot

init_notebook_mode(connected = True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
trace0 = go.Box(
        name = "FIT",
        y = df['SALARY'])

layout = go.Layout(
        title = "FIT Faculty Salary")

data = [trace0]
iplot({"data":data,
       "layout":layout
      })
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~tngai/80.embed" height="525px" width="100%"></iframe>
